# %% [markdown]
# # Optimization using SciPy

# %% [markdown]
# ### Simple Optimization (Minimum and Maximum)

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def f(x):
    return x**2 -2*x-1

# %%
f(0)

# %%
x = np.linspace(-5, 5, 100)

# %%
y = f(x)
y
# Out:
# array([34.        , 32.79808183, 31.61656974, 30.45546373, 29.3147638 ,
#        28.19446995, 27.09458219, 26.0151005 , 24.9560249 , 23.91735537,
#        22.89909193, 21.90123457, 20.92378329, 19.96673809, 19.03009897,
#        18.11386593, 17.21803898, 16.3426181 , 15.48760331, 14.65299459,
#        13.83879196, 13.04499541, 12.27160494, 11.51862055, 10.78604224,
#        10.07387001,  9.38210387,  8.7107438 ,  8.05978982,  7.42924191,
#         6.81910009,  6.22936435,  5.66003469,  5.11111111,  4.58259361,
#         4.0744822 ,  3.58677686,  3.1194776 ,  2.67258443,  2.24609734,
#         1.84001632,  1.45434139,  1.08907254,  0.74420977,  0.41975309,
#         0.11570248, -0.16794205, -0.43118049, -0.67401286, -0.89643914,
#        -1.09845934, -1.28007346, -1.4412815 , -1.58208346, -1.70247934,
#        -1.80246914, -1.88205285, -1.94123049, -1.98000204, -1.99836751,
#        -1.99632691, -1.97388022, -1.93102745, -1.8677686 , -1.78410366,
#        -1.68003265, -1.55555556, -1.41067238, -1.24538312, -1.05968779,
#        -0.85358637, -0.62707887, -0.38016529, -0.11284563,  0.17488011,
#         0.48301194,  0.81154984,  1.16049383,  1.52984389,  1.91960004,
#         2.32976227,  2.76033058,  3.21130497,  3.68268544,  4.17447199,
#         4.68666463,  5.21926334,  5.77226814,  6.34567901,  6.93949597,
#         7.55371901,  8.18834813,  8.84338333,  9.51882461, 10.21467197,
#        10.93092542, 11.66758494, 12.42465055, 13.20212223, 14.        ])

# %%
fig = plt.figure(figsize=(5, 4), dpi=80)
plt.plot(x, y)
plt.grid('on')
plt.show()

# %%
pip install scipy

# %%
import scipy.optimize as opt # to find the max or min of functions

# %% [markdown]
# - Find a minimum of the function `f(x)` using the BFGS (Broyden–Fletcher–Goldfarb–Shanno) method, starting from a initial point `x0 = 0`.

# %%
x0 = 0 
[xopt, fopt, gopt, Bopt, func_calls, grad_calls, warnflg] = \
    opt.fmin_bfgs(f,  # Objective function to be minimized.
              x0=x0,  # Initial guess.
              maxiter=1000,  # Maximum number of iterations to perform.
              full_output=True)  # Return fopt, func_calls, grad_calls, and warnflag in addition to xopt.
# Out:
# Optimization terminated successfully.
#          Current function value: -2.000000
#          Iterations: 2
#          Function evaluations: 6
#          Gradient evaluations: 3

# %%
xopt
# Out:
# array([0.99999999])

# %%
fopt
# Out:
# -2.0

# %%
fig = plt.figure(figsize=(5, 4), dpi=80)
plt.plot(x, y)
plt.plot([x0, xopt[0]], [f(x0), fopt], 'o')
plt.grid('on')
plt.show()

# %% [markdown]
# - What if we start from x0 = 4?

# %%
x0 = 4 
[xopt, fopt, gopt, Bopt, func_calls, grad_calls, warnflg] = \
    opt.fmin_bfgs(f,  # Objective function to be minimized.
              x0=x0,  # Initial guess.
              maxiter=2000,  # Maximum number of iterations to perform.
              full_output=True)  # Return fopt, func_calls, grad_calls, and warnflag in addition to xopt.
# Out:
# Optimization terminated successfully.
#          Current function value: -2.000000
#          Iterations: 2
#          Function evaluations: 6
#          Gradient evaluations: 3

# %%
xopt
# Out:
# array([0.99999997])

# %%
fopt
# Out:
# -1.9999999999999991

# %%
fig = plt.figure(figsize=(5, 4), dpi=80)
plt.plot(x, y)
plt.plot([x0, xopt[0]], [f(x0), fopt], 'o')
plt.grid('on')
plt.show()

# %% [markdown]
# - Define a function: $f(x) = x^2+10\sin(x)$
# - Define a line x from -10 to 10 with 51 points
# - Plot the function f
# - Find the optimal solution with initial value x=0
# - Plot the function with the solution
# - Change the initial value to x=6 and find the optimal solution
# - Plot the function with the solution

# %%
def f(x):
    return x**2 + (10*np.sin(x))
x = np.linspace(-10,10,51)
y=f(x)
x0=0
[xopt, fopt, gopt, Bopt, func_calls, grad_calls, warnflg] = \
    opt.fmin_bfgs(f,  
              x0=x0, 
              maxiter=2000,  
              full_output=True)
# Out:
# Optimization terminated successfully.
#          Current function value: -7.945823
#          Iterations: 5
#          Function evaluations: 12
#          Gradient evaluations: 6

# %%
fig = plt.figure(figsize=(5, 4), dpi=80)
plt.plot(x, y)
plt.plot([x0, xopt[0]], [f(x0), fopt], 'o')
plt.grid('on')
plt.show()

# %%
xopt=xopt[0]
print(xopt)
# Out:
# -1.3064401160169776

# %%
fopt
# Out:
# -7.945823375615215

# %%
x0 = 6
[xopt, fopt, gopt, Bopt, func_calls, grad_calls, warnflg] = \
    opt.fmin_bfgs(f,  # Objective function to be minimized.
              x0=x0,  # Initial guess.
              maxiter=2000,  # Maximum number of iterations to perform.
              full_output=True)  # Return fopt, func_calls, grad_calls, and warnflag in addition to xopt.
fig = plt.figure(figsize=(5, 4), dpi=80)
plt.plot(x, y)
plt.plot([x0, xopt[0]], [f(x0), fopt], 'o')
plt.grid('on')
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 8.315586
#          Iterations: 7
#          Function evaluations: 16
#          Gradient evaluations: 8

# %% [markdown]
# - Find the global minimum using the basinhopping method.

# %%
x0=6
res = \
    opt.basinhopping(f, 
                     x0=x0, 
                     T=1,  # The “temperature” parameter
                     stepsize=2)  # Initial step size
res
# Out:
#                     message: ['requested number of basinhopping iterations completed successfully']
#                     success: True
#                         fun: -7.945823375615284
#                           x: [-1.306e+00]
#                         nit: 100
#       minimization_failures: 0
#                        nfev: 1276
#                        njev: 638
#  lowest_optimization_result:  message: Optimization terminated successfully.
#                               success: True
#                                status: 0
#                                   fun: -7.945823375615284
#                                     x: [-1.306e+00]
#                                   nit: 5
#                                   jac: [ 1.192e-07]
#                              hess_inv: [[ 8.583e-02]]
#                                  nfev: 12
#                                  njev: 6

# %%
fig = plt.figure(figsize=(5, 4), dpi=80)
plt.plot(x, y)
plt.plot([x0, res.x[0]], [f(x0), res.fun], 'o')
plt.grid('on')
plt.show()

# %% [markdown]
# ### Solving Equations

# %% [markdown]
# - Solve the equation $f(x)=x^2+10\sin(x)=0$.

# %%
x0 = 2
xopt = opt.fsolve(f, x0)  # Find a root with initial guess x0
xopt
# Out:
# array([0.])

# %%
fig = plt.figure(figsize=(5, 4), dpi=80)
plt.plot(x, y)
plt.plot([x0, xopt[0]], [f(x0), f(xopt[0])], 'o')
plt.grid('on')
plt.show()

# %%
x0 = -4
xopt = opt.fsolve(f, x0)  # Find a root with initial guess x0
xopt
# Out:
# array([-2.47948183])

# %%
fig = plt.figure(figsize=(5, 4), dpi=80)
plt.plot(x, y)
plt.plot([x0, xopt[0]], [f(x0), f(xopt[0])], 'o')
plt.grid('on')
plt.show()

# %% [markdown]
# ### Curve Fitting

# %% [markdown]
# - Curve fitting is a procedure for finding the best-fitting curve to a given set of points by minimizing the sum of the squares of the offsets ("the residuals") of the points from the curve.
# <img src="images/curve_fitting_1.png" alt="Curve Fitting 1" style="width: 150px;"/>
# <img src="images/curve_fitting_2.png" alt="Curve Fitting 2" style="width: 150px;"/>
# <img src="images/curve_fitting_3.png" alt="Curve Fitting 3" style="width: 150px;"/>

# %%
x
# Out:
# array([-10. ,  -9.6,  -9.2,  -8.8,  -8.4,  -8. ,  -7.6,  -7.2,  -6.8,
#         -6.4,  -6. ,  -5.6,  -5.2,  -4.8,  -4.4,  -4. ,  -3.6,  -3.2,
#         -2.8,  -2.4,  -2. ,  -1.6,  -1.2,  -0.8,  -0.4,   0. ,   0.4,
#          0.8,   1.2,   1.6,   2. ,   2.4,   2.8,   3.2,   3.6,   4. ,
#          4.4,   4.8,   5.2,   5.6,   6. ,   6.4,   6.8,   7.2,   7.6,
#          8. ,   8.4,   8.8,   9.2,   9.6,  10. ])

# %%
y
# Out:
# array([105.44021111,  93.90326781,  82.41110086,  71.59082807,
#         62.01401092,  54.10641753,  48.08080328,  43.90332136,
#         41.29886649,  39.79450795,  38.79415498,  37.67266638,
#         35.87454656,  33.00164609,  28.87602074,  23.56802495,
#         17.38520443,  10.82374143,   4.4901185 ,  -0.99463181,
#         -5.09297427,  -7.43573603,  -7.88039086,  -6.53356091,
#         -3.73418342,   0.        ,   4.05418342,   7.81356091,
#         10.76039086,  12.55573603,  13.09297427,  12.51463181,
#         11.1898815 ,   9.65625857,   8.53479557,   8.43197505,
#          9.84397926,  13.07835391,  18.20545344,  25.04733362,
#         33.20584502,  42.12549205,  51.18113351,  59.77667864,
#         67.43919672,  73.89358247,  79.10598908,  83.28917193,
#         86.86889914,  90.41673219,  94.55978889])

# %%
fig = plt.figure(figsize=(5, 4), dpi=80)
plt.plot(x, y, '+')
plt.grid('on')
plt.show()

# %%
y_noise = f(x) + 5*np.random.randn(x.size)  # Add some random noise
y_noise
# Out:
# array([ 98.11428711,  98.08847795,  76.82681279,  73.09570207,
#         67.46633952,  45.50025651,  50.93216779,  48.15942029,
#         40.72433966,  43.02795111,  30.40629814,  47.3023602 ,
#         31.8165624 ,  31.80710904,  30.7374601 ,  20.74889651,
#         11.22485483,   4.1441388 ,  -2.80465673,   1.00395529,
#         -9.03386331, -10.22666981,  -6.14274313, -10.9821158 ,
#         -6.80731324,   1.78610677,   5.47066167,  10.35867487,
#          3.62578797,   6.81906839,  11.78939929,  16.30766818,
#         10.0858481 ,   5.6002614 ,  15.16903355,  12.5107291 ,
#          4.77364376,  18.91865107,  25.76953264,  28.69640361,
#         34.48214708,  40.75175855,  43.15078819,  62.86493373,
#         67.92472272,  75.05969324,  77.57098381,  79.51889817,
#         92.01320696,  87.55171594,  97.36975492])

# %%
fig = plt.figure(figsize=(5, 4), dpi=80)
plt.plot(x, y, '+')
plt.plot(x, y_noise, 'o')
plt.grid('on')
plt.show()

# %% [markdown]
# - Fit a function $f_2(x)=ax^2+b\sin(x)$ by determining the optimal values of the coefficients `a` and `b`.

# %%
def f2(x, a, b):
    return a*x**2 + b*np.sin(x)

# %%
guess = [2, 2]  # Initial guess for a and b, respectively
params, cov = opt.curve_fit(f2, x, y_noise, guess)
params
# Out:
# array([0.9967473 , 8.83862898])

# %%
a = params[0]
b = params[1]
y_fit = f2(x, a, b)
y_fit
# Out:
# array([104.4831311 ,  93.40104123,  82.39465051,  72.01824513,
#         62.77700706,  55.04725695,  49.01704138,  44.65644443,
#         41.72231073,  39.79663437,  38.35255284,  36.83752704,
#         34.76057501,  31.76978725,  27.70788546,  22.63705332,
#         16.82911907,  10.72263978,   4.85366289,  -0.22890397,
#         -4.04995337,  -6.28318712,  -6.80263156,  -5.70252606,
#         -3.28244468,   0.        ,   3.60140381,   6.97836261,
#          9.67326379,  11.38653331,  12.0239318 ,  11.71143291,
#         10.77533483,   9.69074499,   9.00657104,   9.25886039,
#         10.88617013,  14.16032849,  19.14351916,  25.67846384,
#         33.413253  ,  41.85690473,  50.4568799 ,  58.68631599,
#         66.12720711,  72.53639789,  77.88397241,  82.35797723,
#         86.33473302,  90.31942175,  94.86632959])

# %%
fig = plt.figure(figsize=(5, 4), dpi=80)
plt.plot(x, y_fit)
plt.plot(x, y_noise, 'o')
plt.grid('on')
plt.show()
